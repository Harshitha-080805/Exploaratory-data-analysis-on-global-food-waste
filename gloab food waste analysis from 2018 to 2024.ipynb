# %% [markdown]
# # <b>Project Title: Exploratory Data Analysis of Global Food Waste Trends Across Regions<b>

# %% [markdown]
# # Importing Libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # Reading .csv File

# %%
data=pd.read_csv("global_food_wastage_dataset.csv")
data
# Out:
#         Country  Year        Food Category  Total Waste (Tons)  \
# 0     Australia  2019  Fruits & Vegetables            19268.63
# 1     Indonesia  2019        Prepared Food             3916.97
# 2       Germany  2022       Dairy Products             9700.16
# 3        France  2023  Fruits & Vegetables            46299.69
# 4        France  2023            Beverages            33096.57
# ...         ...   ...                  ...                 ...
# 4995     France  2021            Beverages            47524.74
# 4996  Australia  2021            Beverages            32337.72
# 4997      China  2018       Meat & Seafood            20640.96
# 4998  Australia  2021            Beverages            26566.64
# 4999     France  2024         Bakery Items             8860.27
#
#       Economic Loss (Million $)  Avg Waste per Capita (Kg)  \
# 0                      18686.68                      72.69
# 1                       4394.48                     192.52
# ...

# %% [markdown]
# # Basic Functions

# %% [markdown]
# ### 1. Show first 5 rows

# %%
data.head()
# Out:
#      Country  Year        Food Category  Total Waste (Tons)  \
# 0  Australia  2019  Fruits & Vegetables            19268.63
# 1  Indonesia  2019        Prepared Food             3916.97
# 2    Germany  2022       Dairy Products             9700.16
# 3     France  2023  Fruits & Vegetables            46299.69
# 4     France  2023            Beverages            33096.57
#
#    Economic Loss (Million $)  Avg Waste per Capita (Kg)  Population (Million)  \
# 0                   18686.68                      72.69                 87.59
# 1                    4394.48                     192.52               1153.99
# 2                    8909.16                     166.94               1006.11
# 3                   40551.22                     120.19                953.05
# 4                   36980.82                     104.74               1105.47
#
#    Household Waste (%)
# 0                53.64
# 1                30.61
# 2                48.08
# 3                31.91
# ...

# %% [markdown]
# ### 2. Show last 5 rows

# %%
data.tail()
# Out:
#         Country  Year   Food Category  Total Waste (Tons)  \
# 4995     France  2021       Beverages            47524.74
# 4996  Australia  2021       Beverages            32337.72
# 4997      China  2018  Meat & Seafood            20640.96
# 4998  Australia  2021       Beverages            26566.64
# 4999     France  2024    Bakery Items             8860.27
#
#       Economic Loss (Million $)  Avg Waste per Capita (Kg)  \
# 4995                   48058.40                      77.41
# 4996                   32705.08                     194.35
# 4997                   22485.33                      21.04
# 4998                   29357.57                     197.14
# 4999                    7360.38                      51.50
#
#       Population (Million)  Household Waste (%)
# 4995               1087.46                39.73
# 4996               1336.32                64.83
# 4997                 16.13                31.23
# 4998               1086.17                69.95
# ...

# %% [markdown]
# ### 3. Show column names

# %%
print(data.columns)
# Out:
# Index(['Country', 'Year', 'Food Category', 'Total Waste (Tons)',
#        'Economic Loss (Million $)', 'Avg Waste per Capita (Kg)',
#        'Population (Million)', 'Household Waste (%)'],
#       dtype='object')

# %% [markdown]
# ### 4. Show data shape

# %%
print(data.shape)
# Out:
# (5000, 8)

# %% [markdown]
# ### 5. Show data types

# %%
print(data.dtypes)
# Out:
# Country                       object
# Year                           int64
# Food Category                 object
# Total Waste (Tons)           float64
# Economic Loss (Million $)    float64
# Avg Waste per Capita (Kg)    float64
# Population (Million)         float64
# Household Waste (%)          float64
# dtype: object

# %% [markdown]
# ### 6. Check for missing values

# %%
print(data.isnull().sum())
# Out:
# Country                      0
# Year                         0
# Food Category                0
# Total Waste (Tons)           0
# Economic Loss (Million $)    0
# Avg Waste per Capita (Kg)    0
# Population (Million)         0
# Household Waste (%)          0
# dtype: int64

# %% [markdown]
# ### 7. Check for any nulls in the dataset(other way)

# %%
print(data.isnull().values.any())
# Out:
# False

# %% [markdown]
# ### 8. Get unique countries

# %%
print(data['Country'].unique())
# Out:
# ['Australia' 'Indonesia' 'Germany' 'France' 'India' 'China' 'UK'
#  'South Africa' 'Japan' 'USA' 'Brazil' 'Saudi Arabia' 'Italy' 'Spain'
#  'Mexico' 'Argentina' 'Canada' 'South Korea' 'Russia' 'Turkey']

# %% [markdown]
# ### 9. Count unique food categories

# %%
print(data['Food Category'].nunique())
# Out:
# 8

# %% [markdown]
# ### 10. Show summary statistics

# %%
data.describe()
# Out:
#               Year  Total Waste (Tons)  Economic Loss (Million $)  \
# count  5000.000000         5000.000000                5000.000000
# mean   2021.015600        25061.780072               25039.703870
# std       1.999239        14245.119588               14620.236429
# min    2018.000000          502.610000                 406.690000
# 25%    2019.000000        12783.737500               12612.477500
# 50%    2021.000000        24865.220000               24428.155000
# 75%    2023.000000        37471.035000               37146.037500
# max    2024.000000        49990.760000               59228.930000
#
#        Avg Waste per Capita (Kg)  Population (Million)  Household Waste (%)
# count                 5000.00000           5000.000000          5000.000000
# mean                   109.46397            706.606416            50.060890
# std                     51.93373            402.546464            11.596203
# ...

# %% [markdown]
# ### 11. Check number of duplicates

# %%
print(data.duplicated().sum())
# Out:
# 0

# %% [markdown]
# ### 12. Show basic info

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 8 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Country                    5000 non-null   object
#  1   Year                       5000 non-null   int64
#  2   Food Category              5000 non-null   object
#  3   Total Waste (Tons)         5000 non-null   float64
#  4   Economic Loss (Million $)  5000 non-null   float64
#  5   Avg Waste per Capita (Kg)  5000 non-null   float64
#  6   Population (Million)       5000 non-null   float64
#  7   Household Waste (%)        5000 non-null   float64
# dtypes: float64(5), int64(1), object(2)
# memory usage: 312.6+ KB

# %% [markdown]
# ### 13. Value counts of a column

# %%
print(data['Year'].value_counts())
# Out:
# Year
# 2023    737
# 2021    734
# 2020    731
# 2024    721
# 2018    708
# 2019    691
# 2022    678
# Name: count, dtype: int64

# %% [markdown]
# ### 14. Minimum Economic Loss

# %%
print(data['Economic Loss (Million $)'].min())
# Out:
# 406.69

# %% [markdown]
# ### 15. Maximum Household Waste %

# %%
print(data['Household Waste (%)'].max())
# Out:
# 70.0

# %% [markdown]
# ### 16. Mean Waste per Capita

# %%
print(data['Avg Waste per Capita (Kg)'].mean())
# Out:
# 109.46396999999999

# %% [markdown]
# ### 17. Check for any nulls in the dataset

# %%
print(data.isnull().values.any())
# Out:
# False

# %% [markdown]
# # Data Cleaning

# %% [markdown]
# ### 1. Strip whitespace from string columns

# %%
data_cleaned = data.copy()
data_cleaned['Country'] = data_cleaned['Country'].str.strip()
data_cleaned['Food Category'] = data_cleaned['Food Category'].str.strip()
print(data_cleaned['Country'])
# Out:
# 0       Australia
# 1       Indonesia
# 2         Germany
# 3          France
# 4          France
#           ...
# 4995       France
# 4996    Australia
# 4997        China
# 4998    Australia
# 4999       France
# Name: Country, Length: 5000, dtype: object

# %% [markdown]
# ### 2. Drop rows with any missing values

# %%
data_cleaned = data_cleaned.dropna()
data_cleaned
# Out:
#         Country  Year        Food Category  Total Waste (Tons)  \
# 0     Australia  2019  Fruits & Vegetables            19268.63
# 1     Indonesia  2019        Prepared Food             3916.97
# 2       Germany  2022       Dairy Products             9700.16
# 3        France  2023  Fruits & Vegetables            46299.69
# 4        France  2023            Beverages            33096.57
# ...         ...   ...                  ...                 ...
# 4995     France  2021            Beverages            47524.74
# 4996  Australia  2021            Beverages            32337.72
# 4997      China  2018       Meat & Seafood            20640.96
# 4998  Australia  2021            Beverages            26566.64
# 4999     France  2024         Bakery Items             8860.27
#
#       Economic Loss (Million $)  Avg Waste per Capita (Kg)  \
# 0                      18686.68                      72.69
# 1                       4394.48                     192.52
# ...

# %% [markdown]
# ## Data Filtering

# %% [markdown]
# ### 1. Filter data where Country is 'France' and Year is 2023

# %%
france_2023 = data[(data['Country'] == 'France') & (data['Year'] == 2023)]
france_2023
# Out:
#      Country  Year        Food Category  Total Waste (Tons)  \
# 3     France  2023  Fruits & Vegetables            46299.69
# 4     France  2023            Beverages            33096.57
# 83    France  2023        Prepared Food            45216.87
# 195   France  2023     Grains & Cereals            42544.59
# 196   France  2023         Bakery Items            15275.97
# 205   France  2023       Dairy Products            16869.71
# 276   France  2023     Grains & Cereals            13851.18
# 385   France  2023         Bakery Items            24942.52
# 445   France  2023     Grains & Cereals            17060.48
# 688   France  2023          Frozen Food            20381.90
# 717   France  2023          Frozen Food              692.30
# 864   France  2023  Fruits & Vegetables            42584.45
# 1201  France  2023         Bakery Items            44497.57
# 1384  France  2023            Beverages            45126.17
# 1412  France  2023         Bakery Items            13901.18
# ...

# %% [markdown]
# ### 2. Filter rows where Economic Loss is above 30000

# %%
high_loss = data[data['Economic Loss (Million $)'] > 30000]
high_loss
# Out:
#            Country  Year        Food Category  Total Waste (Tons)  \
# 3           France  2023  Fruits & Vegetables            46299.69
# 4           France  2023            Beverages            33096.57
# 6          Germany  2024        Prepared Food            45038.72
# 10    South Africa  2024          Frozen Food            39478.70
# 11           Japan  2022          Frozen Food            41025.90
# ...            ...   ...                  ...                 ...
# 4992         China  2018     Grains & Cereals            48984.17
# 4993        France  2021     Grains & Cereals            42126.64
# 4994     Indonesia  2023        Prepared Food            39980.40
# 4995        France  2021            Beverages            47524.74
# 4996     Australia  2021            Beverages            32337.72
#
#       Economic Loss (Million $)  Avg Waste per Capita (Kg)  \
# 3                      40551.22                     120.19
# ...

# %% [markdown]
# ### 3. Filter data where Food Category is 'Fruits & Vegetables'

# %%
fruits_veg_data = data[data['Food Category'] == 'Fruits & Vegetables']
fruits_veg_data
# Out:
#            Country  Year        Food Category  Total Waste (Tons)  \
# 0        Australia  2019  Fruits & Vegetables            19268.63
# 3           France  2023  Fruits & Vegetables            46299.69
# 5            India  2024  Fruits & Vegetables            11962.89
# 7            China  2019  Fruits & Vegetables            12791.20
# 20    Saudi Arabia  2019  Fruits & Vegetables            10653.37
# ...            ...   ...                  ...                 ...
# 4942     Australia  2020  Fruits & Vegetables            33225.07
# 4958        Canada  2021  Fruits & Vegetables            44681.18
# 4982  South Africa  2018  Fruits & Vegetables            46466.94
# 4983        Brazil  2018  Fruits & Vegetables            18801.21
# 4988  Saudi Arabia  2019  Fruits & Vegetables            44319.58
#
#       Economic Loss (Million $)  Avg Waste per Capita (Kg)  \
# 0                      18686.68                      72.69
# ...

# %% [markdown]
# ### 4. Filter data where Avg Waste per Capita is greater than 150 Kg

# %%
high_per_capita_waste = data[data['Avg Waste per Capita (Kg)'] > 150]
high_per_capita_waste
# Out:
#            Country  Year        Food Category  Total Waste (Tons)  \
# 1        Indonesia  2019        Prepared Food             3916.97
# 2          Germany  2022       Dairy Products             9700.16
# 6          Germany  2024        Prepared Food            45038.72
# 10    South Africa  2024          Frozen Food            39478.70
# 17    Saudi Arabia  2020        Prepared Food            18483.82
# ...            ...   ...                  ...                 ...
# 4975     Argentina  2023     Grains & Cereals            21088.70
# 4976        Canada  2018            Beverages            44473.73
# 4982  South Africa  2018  Fruits & Vegetables            46466.94
# 4996     Australia  2021            Beverages            32337.72
# 4998     Australia  2021            Beverages            26566.64
#
#       Economic Loss (Million $)  Avg Waste per Capita (Kg)  \
# 1                       4394.48                     192.52
# ...

# %% [markdown]
# ### 5. Filter data where Household Waste (%) is more than 35%

# %%
high_household_waste = data[data['Household Waste (%)'] > 35]
high_household_waste
# Out:
#         Country  Year        Food Category  Total Waste (Tons)  \
# 0     Australia  2019  Fruits & Vegetables            19268.63
# 2       Germany  2022       Dairy Products             9700.16
# 4        France  2023            Beverages            33096.57
# 5         India  2024  Fruits & Vegetables            11962.89
# 6       Germany  2024        Prepared Food            45038.72
# ...         ...   ...                  ...                 ...
# 4994  Indonesia  2023        Prepared Food            39980.40
# 4995     France  2021            Beverages            47524.74
# 4996  Australia  2021            Beverages            32337.72
# 4998  Australia  2021            Beverages            26566.64
# 4999     France  2024         Bakery Items             8860.27
#
#       Economic Loss (Million $)  Avg Waste per Capita (Kg)  \
# 0                      18686.68                      72.69
# 2                       8909.16                     166.94
# ...

# %% [markdown]
# ### 6. Filter data where Population is less than 1000 million and Economic Loss is below 30000

# %%
low_pop_low_loss = data[(data['Population (Million)'] < 1000) & (data['Economic Loss (Million $)'] < 30000)]
low_pop_low_loss
# Out:
#            Country  Year        Food Category  Total Waste (Tons)  \
# 0        Australia  2019  Fruits & Vegetables            19268.63
# 8               UK  2019       Meat & Seafood            14795.65
# 9            India  2019     Grains & Cereals            12118.32
# 12             USA  2024            Beverages            22924.85
# 14             USA  2022         Bakery Items            32457.98
# ...            ...   ...                  ...                 ...
# 4989  South Africa  2022       Meat & Seafood             3925.48
# 4990            UK  2021          Frozen Food            21794.85
# 4991        France  2019       Meat & Seafood            26583.09
# 4997         China  2018       Meat & Seafood            20640.96
# 4999        France  2024         Bakery Items             8860.27
#
#       Economic Loss (Million $)  Avg Waste per Capita (Kg)  \
# 0                      18686.68                      72.69
# ...

# %% [markdown]
# ## Grouping

# %% [markdown]
# ### 1.Group by Country and sum total waste

# %%
grouped_waste = data.groupby('Country')['Total Waste (Tons)'].sum()
grouped_waste
# Out:
# Country
# Argentina       6082367.52
# Australia       5887361.29
# Brazil          6391752.50
# Canada          6790678.49
# China           6411096.18
# France          6334495.00
# Germany         6760053.01
# India           6245313.77
# Indonesia       6294447.74
# Italy           6207707.28
# Japan           5907491.06
# Mexico          6589169.52
# Russia          5832689.46
# Saudi Arabia    5983283.87
# South Africa    6056470.30
# South Korea     5609107.07
# Spain           6790574.25
# Turkey          6879885.81
# UK              5808621.61
# USA             6446334.63
# Name: Total Waste (Tons), dtype: float64

# %% [markdown]
# ### 2. Group by Year and average economic loss

# %%
grouped_loss = data.groupby('Year')['Economic Loss (Million $)'].mean()
grouped_loss
# Out:
# Year
# 2018    24912.419449
# 2019    25478.833922
# 2020    24636.066129
# 2021    24922.222234
# 2022    25148.801431
# 2023    25047.470380
# 2024    25162.140971
# Name: Economic Loss (Million $), dtype: float64

# %% [markdown]
# ## Sorting

# %% [markdown]
# ### 1.Sort by Economic Loss descending

# %%
sorted_loss = data.sort_values(by='Economic Loss (Million $)', ascending=False)
sorted_loss
# Out:
#            Country  Year        Food Category  Total Waste (Tons)  \
# 1952         India  2022  Fruits & Vegetables            49620.52
# 4444  South Africa  2021            Beverages            49192.28
# 437      Argentina  2021  Fruits & Vegetables            49285.44
# 928         Turkey  2023       Dairy Products            49901.29
# 2837       Germany  2021            Beverages            49657.88
# ...            ...   ...                  ...                 ...
# 1110           USA  2022            Beverages              506.76
# 1278        Russia  2024  Fruits & Vegetables              563.82
# 415         Mexico  2023       Meat & Seafood              515.30
# 3423         Spain  2018       Meat & Seafood              504.23
# 618          India  2018     Grains & Cereals              502.61
#
#       Economic Loss (Million $)  Avg Waste per Capita (Kg)  \
# 1952                   59228.93                      65.58
# ...

# %% [markdown]
# ### 2. Sort by Avg Waste per Capita ascending

# %%
sorted_capita = data.sort_values(by='Avg Waste per Capita (Kg)', ascending=True)
sorted_capita
# Out:
#            Country  Year        Food Category  Total Waste (Tons)  \
# 354      Indonesia  2019            Beverages            23745.49
# 2484  South Africa  2023  Fruits & Vegetables            47213.86
# 2091           USA  2020       Dairy Products            14176.85
# 4545        Russia  2022            Beverages             2849.62
# 2430       Germany  2020         Bakery Items            37792.37
# ...            ...   ...                  ...                 ...
# 495          Japan  2021            Beverages             2124.68
# 3276     Indonesia  2022         Bakery Items            39060.62
# 2941        Mexico  2020        Prepared Food             7255.60
# 3489       Germany  2021        Prepared Food            13820.66
# 3439         Japan  2020         Bakery Items             5536.51
#
#       Economic Loss (Million $)  Avg Waste per Capita (Kg)  \
# 354                    20351.51                      20.09
# ...

# %% [markdown]
# ## Aggregation

# %% [markdown]
# ### 1.Total Waste (Tons) by Country

# %%
total_waste_by_country = data.groupby('Country')['Total Waste (Tons)'].describe()
total_waste_by_country
# Out:
#               count          mean           std      min         25%  \
# Country
# Argentina     238.0  25556.166050  14445.065288   665.76  13076.7275
# Australia     226.0  26050.271195  14538.580496   795.69  13876.7150
# Brazil        258.0  24774.234496  13790.160831   574.78  13846.6525
# Canada        254.0  26734.954685  14166.688080   578.58  15141.5325
# China         262.0  24469.832748  14667.454444   635.89  11410.5000
# France        239.0  26504.163180  14329.673827   692.30  15326.7350
# Germany       287.0  23554.191672  13598.662229   740.99  12201.1500
# India         257.0  24300.831790  13813.263074   502.61  12982.7000
# Indonesia     244.0  25796.916967  14243.997060   628.70  13962.9300
# Italy         253.0  24536.392411  14113.759687   517.61  13160.7400
# Japan         240.0  24614.546083  15357.237918  1175.38   9331.3600
# Mexico        251.0  26251.671394  14385.639375   515.30  13426.4000
# ...

# %% [markdown]
# ### 2. Year-wise Average Waste per Capita

# %%
avg_per_capita_by_year = data.groupby('Year')['Avg Waste per Capita (Kg)'].mean()
avg_per_capita_by_year
# Out:
# Year
# 2018    108.928150
# 2019    107.818973
# 2020    110.850479
# 2021    107.362166
# 2022    110.389012
# 2023    109.681031
# 2024    111.208890
# Name: Avg Waste per Capita (Kg), dtype: float64

# %% [markdown]
# ### 3.Maximum Avg Waste per Capita by Food Category

# %%
max_per_capita_by_cate = data.groupby('Food Category')['Avg Waste per Capita (Kg)'].max()
max_per_capita_by_cate
# Out:
# Food Category
# Bakery Items           199.97
# Beverages              199.84
# Dairy Products         199.71
# Frozen Food            199.44
# Fruits & Vegetables    199.83
# Grains & Cereals       199.22
# Meat & Seafood         198.75
# Prepared Food          199.93
# Name: Avg Waste per Capita (Kg), dtype: float64

# %% [markdown]
# ### 4. Country with maximum Total Waste

# %%
country_max_waste = data.groupby('Country')['Total Waste (Tons)'].sum().idxmax()
country_max_waste
# Out:
# 'Turkey'

# %% [markdown]
# ### 5. Economic Loss and Total Waste by Country and Year

# %%
l = data.groupby(['Country', 'Year'])[
    ['Economic Loss (Million $)', 'Total Waste (Tons)']
].sum()
l
# Out:
#                 Economic Loss (Million $)  Total Waste (Tons)
# Country   Year
# Argentina 2018                  697747.19           698608.25
#           2019                 1123070.99          1118055.87
#           2020                 1084595.22          1044925.92
#           2021                 1055098.58          1049654.59
#           2022                  716812.77           720036.35
# ...                                   ...                 ...
# USA       2020                  716529.59           692943.94
#           2021                  704778.64           703433.90
#           2022                 1230654.24          1240270.48
#           2023                  879539.06           864642.36
#           2024                  943432.91           945506.12
#
# [140 rows x 2 columns]

# %% [markdown]
# ## Queries

# %% [markdown]
# ### 1.Rows where Population is above average population ?

# %%
a = data[data['Population (Million)'] > data['Population (Million)'].mean()]
a
# Out:
#         Country  Year        Food Category  Total Waste (Tons)  \
# 1     Indonesia  2019        Prepared Food             3916.97
# 2       Germany  2022       Dairy Products             9700.16
# 3        France  2023  Fruits & Vegetables            46299.69
# 4        France  2023            Beverages            33096.57
# 5         India  2024  Fruits & Vegetables            11962.89
# ...         ...   ...                  ...                 ...
# 4993     France  2021     Grains & Cereals            42126.64
# 4995     France  2021            Beverages            47524.74
# 4996  Australia  2021            Beverages            32337.72
# 4998  Australia  2021            Beverages            26566.64
# 4999     France  2024         Bakery Items             8860.27
#
#       Economic Loss (Million $)  Avg Waste per Capita (Kg)  \
# 1                       4394.48                     192.52
# 2                       8909.16                     166.94
# ...

# %% [markdown]
# ### 2.Rows where Food Category is 'Prepared Food' ?

# %%
n = data[data['Food Category'] == 'Prepared Food']
n
# Out:
#            Country  Year  Food Category  Total Waste (Tons)  \
# 1        Indonesia  2019  Prepared Food             3916.97
# 6          Germany  2024  Prepared Food            45038.72
# 17    Saudi Arabia  2020  Prepared Food            18483.82
# 19           China  2018  Prepared Food            11314.08
# 24    Saudi Arabia  2024  Prepared Food            33085.77
# ...            ...   ...            ...                 ...
# 4962     Indonesia  2023  Prepared Food            15185.55
# 4967           USA  2019  Prepared Food            24982.19
# 4968        Turkey  2021  Prepared Food             9867.52
# 4977         Japan  2019  Prepared Food            43392.94
# 4994     Indonesia  2023  Prepared Food            39980.40
#
#       Economic Loss (Million $)  Avg Waste per Capita (Kg)  \
# 1                       4394.48                     192.52
# 6                      39191.25                     179.27
# 17                     21071.65                     198.62
# ...

# %% [markdown]
# ### 3.Find the country-year combination with minimum Economic Loss ?

# %%
min_loss = data.loc[data['Economic Loss (Million $)'].idxmin()]
min_loss
# Out:
# Country                                 India
# Year                                     2018
# Food Category                Grains & Cereals
# Total Waste (Tons)                     502.61
# Economic Loss (Million $)              406.69
# Avg Waste per Capita (Kg)              159.84
# Population (Million)                   818.87
# Household Waste (%)                      66.1
# Name: 618, dtype: object

# %% [markdown]
# ### 4. Find the top 5 countries with highest Avg Waste per Capita ?

# %%
t = data.groupby('Country')['Avg Waste per Capita (Kg)'].mean().nlargest(5)
t
# Out:
# Country
# Germany         115.727178
# Saudi Arabia    114.503180
# South Korea     113.139212
# Italy           112.192372
# France          111.942720
# Name: Avg Waste per Capita (Kg), dtype: float64

# %% [markdown]
# ### 5. List all unique Food Categories ?

# %%
un = data['Food Category'].unique()
un
# Out:
# array(['Fruits & Vegetables', 'Prepared Food', 'Dairy Products',
#        'Beverages', 'Meat & Seafood', 'Grains & Cereals', 'Frozen Food',
#        'Bakery Items'], dtype=object)

# %% [markdown]
# ### 6. Count of entries for each Year ?

# %%
c = data['Year'].value_counts()
c
# Out:
# Year
# 2023    737
# 2021    734
# 2020    731
# 2024    721
# 2018    708
# 2019    691
# 2022    678
# Name: count, dtype: int64

# %% [markdown]
# ### 7. Data where Economic Loss is greater than Total Waste * 1  ?

# %%
l = data[data['Economic Loss (Million $)'] > data['Total Waste (Tons)']]
l
# Out:
#            Country  Year     Food Category  Total Waste (Tons)  \
# 1        Indonesia  2019     Prepared Food             3916.97
# 4           France  2023         Beverages            33096.57
# 9            India  2019  Grains & Cereals            12118.32
# 10    South Africa  2024       Frozen Food            39478.70
# 13          France  2018         Beverages            29295.07
# ...            ...   ...               ...                 ...
# 4992         China  2018  Grains & Cereals            48984.17
# 4995        France  2021         Beverages            47524.74
# 4996     Australia  2021         Beverages            32337.72
# 4997         China  2018    Meat & Seafood            20640.96
# 4998     Australia  2021         Beverages            26566.64
#
#       Economic Loss (Million $)  Avg Waste per Capita (Kg)  \
# 1                       4394.48                     192.52
# 4                      36980.82                     104.74
# ...

# %% [markdown]
# ### 8. Countries with at least one entry where Household Waste (%) is exactly 50 ?

# %%
z = data[data['Household Waste (%)'] == 50]['Country']
z
# Out:
# 1156    Japan
# Name: Country, dtype: object

# %% [markdown]
# ### 9. Total Waste (Tons) by Food Category, sorted descending ?

# %%
waste_by_category = data.groupby('Food Category')['Total Waste (Tons)'].sum().sort_values(ascending=False)
waste_by_category
# Out:
# Food Category
# Prepared Food          17929317.92
# Beverages              16354455.29
# Bakery Items           15587955.51
# Fruits & Vegetables    15522081.20
# Meat & Seafood         15371347.52
# Dairy Products         15292167.33
# Frozen Food            15045115.02
# Grains & Cereals       14206460.57
# Name: Total Waste (Tons), dtype: float64

# %% [markdown]
# ### 10. Check if any country has Economic Loss over 100000 ?

# %%
any_loss_over = (data['Economic Loss (Million $)'] > 100000).any()
any_loss_over
# Out:
# False

# %% [markdown]
# ### 11. Data where both Economic Loss and Total Waste are in top 10% ?

# %%
top = data[
    (data['Economic Loss (Million $)'] > data['Economic Loss (Million $)'].quantile(0.9)) &
    (data['Total Waste (Tons)'] > data['Total Waste (Tons)'].quantile(0.9))
]
top
# Out:
#            Country  Year        Food Category  Total Waste (Tons)  \
# 30       Argentina  2020         Bakery Items            49310.46
# 53       Argentina  2019        Prepared Food            49481.61
# 67           Japan  2019          Frozen Food            47373.71
# 73         Germany  2023        Prepared Food            46296.01
# 83          France  2023        Prepared Food            45216.87
# ...            ...   ...                  ...                 ...
# 4922        Russia  2024            Beverages            45578.99
# 4953     Indonesia  2021       Meat & Seafood            45420.52
# 4982  South Africa  2018  Fruits & Vegetables            46466.94
# 4992         China  2018     Grains & Cereals            48984.17
# 4995        France  2021            Beverages            47524.74
#
#       Economic Loss (Million $)  Avg Waste per Capita (Kg)  \
# 30                     49520.57                      21.69
# ...

# %% [markdown]
# ### 12. Compute correlation between Economic Loss and Total Waste ?

# %%
correlation = data['Economic Loss (Million $)'].corr(data['Total Waste (Tons)'])
correlation
# Out:
# 0.9745219286512483

# %% [markdown]
# ### 13. Add a new column: Economic Loss per Ton

# %%
data['Loss per Ton'] = data['Economic Loss (Million $)'] / data['Total Waste (Tons)']
data['Loss per Ton']
# Out:
# 0       0.969798
# 1       1.121908
# 2       0.918455
# 3       0.875842
# 4       1.117361
#           ...
# 4995    1.011229
# 4996    1.011360
# 4997    1.089355
# 4998    1.105054
# 4999    0.830717
# Name: Loss per Ton, Length: 5000, dtype: float64

# %% [markdown]
# ### 14. Top 3 years with highest total Food Waste ?

# %%
top3_waste_years = data.groupby('Year')['Total Waste (Tons)'].sum().nlargest(3)
top3_waste_years
# Out:
# Year
# 2023    18444672.83
# 2021    18305242.89
# 2024    18169859.22
# Name: Total Waste (Tons), dtype: float64

# %% [markdown]
# ### 15. Count of rows per Food Category per Year ?

# %%
category_year_count = data.groupby(['Food Category', 'Year']).size().reset_index(name='Count')
category_year_count
# Out:
#           Food Category  Year  Count
# 0          Bakery Items  2018     98
# 1          Bakery Items  2019     92
# 2          Bakery Items  2020     90
# 3          Bakery Items  2021     76
# 4          Bakery Items  2022     85
# 5          Bakery Items  2023    105
# 6          Bakery Items  2024     84
# 7             Beverages  2018    100
# 8             Beverages  2019     94
# 9             Beverages  2020     98
# 10            Beverages  2021     94
# 11            Beverages  2022     77
# 12            Beverages  2023    103
# 13            Beverages  2024     73
# 14       Dairy Products  2018     87
# 15       Dairy Products  2019     97
# 16       Dairy Products  2020     88
# 17       Dairy Products  2021     84
# 18       Dairy Products  2022     76
# 19       Dairy Products  2023     92
# 20       Dairy Products  2024     92
# 21          Frozen Food  2018     87
# 22          Frozen Food  2019     73
# 23          Frozen Food  2020     87
# ...

# %% [markdown]
# ### 16. Countries with increasing waste trend  ?

# %%
waste_trend = data.groupby(['Country', 'Year'])['Total Waste (Tons)'].sum().reset_index()
waste_trend
# Out:
#        Country  Year  Total Waste (Tons)
# 0    Argentina  2018           698608.25
# 1    Argentina  2019          1118055.87
# 2    Argentina  2020          1044925.92
# 3    Argentina  2021          1049654.59
# 4    Argentina  2022           720036.35
# ..         ...   ...                 ...
# 135        USA  2020           692943.94
# 136        USA  2021           703433.90
# 137        USA  2022          1240270.48
# 138        USA  2023           864642.36
# 139        USA  2024           945506.12
#
# [140 rows x 3 columns]

# %% [markdown]
# ### 17. Countries where average Household Waste is above 40% ?

# %%
high_household_avg = data.groupby('Country')['Household Waste (%)'].mean()
high_household_avg = high_household_avg[high_household_avg > 40]
high_household_avg
# Out:
# Country
# Argentina       50.875168
# Australia       48.593982
# Brazil          50.290000
# Canada          49.096772
# China           49.903282
# France          49.616402
# Germany         49.935052
# India           50.903035
# Indonesia       52.306025
# Italy           48.534427
# Japan           49.528125
# Mexico          50.398606
# Russia          50.621224
# Saudi Arabia    51.040377
# South Africa    48.735918
# South Korea     49.438050
# Spain           50.303321
# Turkey          50.415156
# UK              50.474256
# USA             50.149844
# Name: Household Waste (%), dtype: float64

# %% [markdown]
# ### 18. Median Avg Waste per Capita for each Food Category ?

# %%
median_per_capita = data.groupby('Food Category')['Avg Waste per Capita (Kg)'].median()
median_per_capita
# Out:
# Food Category
# Bakery Items           112.770
# Beverages              109.100
# Dairy Products         111.135
# Frozen Food            111.475
# Fruits & Vegetables    109.380
# Grains & Cereals       106.970
# Meat & Seafood         110.720
# Prepared Food          110.280
# Name: Avg Waste per Capita (Kg), dtype: float64

# %% [markdown]
# ### 19. Data where Population is missing (NaN) ?

# %%
missing_population = data[data['Population (Million)'].isna()]
missing_population
# Out:
# Empty DataFrame
# Columns: [Country, Year, Food Category, Total Waste (Tons), Economic Loss (Million $), Avg Waste per Capita (Kg), Population (Million), Household Waste (%), Loss per Ton]
# Index: []

# %% [markdown]
# ### 20. Countries with the lowest 3 Avg Waste per Capita ?

# %%
lowest3_per_capita = data.groupby('Country')['Avg Waste per Capita (Kg)'].mean().nsmallest(3)
lowest3_per_capita
# Out:
# Country
# UK           100.348760
# Spain        103.471825
# Indonesia    104.834918
# Name: Avg Waste per Capita (Kg), dtype: float64

# %% [markdown]
# ## Visualization

# %% [markdown]
# ### 1. Bar Plot – Total Waste by Country

# %%
waste_by_country = data.groupby('Country')['Total Waste (Tons)'].sum()
waste_by_country.plot(kind='bar', figsize=(10, 5), color='skyblue')
plt.title('Total Food Waste by Country')
plt.ylabel('Waste (Tons)')
plt.xlabel('Country')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %% [markdown]
# ### 2. Line Plot – Economic Loss over Years

# %%
loss_by_year = data.groupby('Year')['Economic Loss (Million $)'].sum()
loss_by_year.plot(kind='line', marker='o', figsize=(8, 4), color='green')
plt.title('Economic Loss Over Years')
plt.ylabel('Economic Loss (Million $)')
plt.xlabel('Year')
plt.grid(True)
plt.tight_layout()
plt.show()

# %% [markdown]
# ### 3. Pie Chart – Food Waste by Category

# %%
waste_by_category = data.groupby('Food Category')['Total Waste (Tons)'].sum()

waste_by_category.plot(kind='pie', autopct='%1.1f%%', startangle=90, figsize=(6, 6))
plt.title('Food Waste Share by Category')
plt.ylabel('')
plt.tight_layout()
plt.show()

# %% [markdown]
# ### 4. Histogram – Distribution of Avg Waste per Capita

# %%
data['Avg Waste per Capita (Kg)'].plot(kind='hist', bins=10, color='orange', edgecolor='black')
plt.title('Distribution of Avg Waste per Capita')
plt.xlabel('Kg per Capita')
plt.tight_layout()
plt.show()

# %% [markdown]
# ### 5. Scatter Plot – Economic Loss vs Total Waste

# %%
plt.scatter(data['Total Waste (Tons)'], data['Economic Loss (Million $)'], color='purple')
plt.title('Economic Loss vs Total Waste')
plt.xlabel('Total Waste (Tons)')
plt.ylabel('Economic Loss (Million $)')
plt.grid(True)
plt.tight_layout()
plt.show()
